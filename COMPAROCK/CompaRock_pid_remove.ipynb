# %% [markdown]
# # Imports

# %%
from abacusnbody.data.compaso_halo_catalog import CompaSOHaloCatalog
from abacusnbody.data.read_abacus import read_asdf
import h5py
import os

import matplotlib.pyplot as plt
from matplotlib import ticker, cm, colors
import matplotlib.colors as mcolors

import numpy as np
import pandas as pd

from scipy.spatial import KDTree, cKDTree
from scipy.spatial.distance import cdist
from scipy.interpolate import griddata, UnivariateSpline, interp1d
from scipy.integrate import quad
from scipy.optimize import linear_sum_assignment, curve_fit

from collections import Counter
from pycorr import TwoPointCorrelationFunction, TwoPointCounter

import psutil
import multiprocessing as mp
from concurrent.futures import ThreadPoolExecutor
import gc
import pickle

import importlib
import functions
importlib.reload(functions)
from functions import *

# %% [markdown]
# ## Halos

# %%
compaso_dir = '/global/cfs/cdirs/desi/cosmosim/Abacus/AbacusSummit_highbase_c000_ph100'

str_z = 'z0.500'
cols = ['id', 'x_L2com', 'v_L2com', 'N', 'r100_L2com']

path_to_sim = os.path.join(compaso_dir, "halos", str_z)
hcat = CompaSOHaloCatalog(path_to_sim, fields=cols, cleaned=True)

# %%
## CompaSo

boxsize_cs = hcat.header['BoxSize']
print("Box size CompaSo:", boxsize_cs)

Mhalos_CS =  hcat.header['ParticleMassHMsun']*hcat.halos['N']

mask = (Mhalos_CS > 10**(11.5))
hcat_pos = hcat.halos[mask]

positions_cs = np.array(hcat_pos['x_L2com'])
positions_cs = positions_cs.astype(np.float64)
positions_cs = (positions_cs + boxsize_cs / 2) % boxsize_cs

Mhalos_CS = Mhalos_CS[mask]
radii_cs = np.array(hcat_pos['r100_L2com'])
# Out:
# Box size CompaSo: 1000.0

# %%
## Rockstar

data = np.load('/pscratch/sd/g/guittonm/rockstar_parent_halos.npz')

mask_RS = (data['masses'] > 10**11.5) # & (data['masses'] < 10**14.5)

Mhalos_RS = data['masses'][mask_RS]
ids_RS = data['ids'][mask_RS]
positions_RS = data['positions'][mask_RS]
velocities_RS = data['velocities'][mask_RS]

file_path_rs = "/global/cfs/cdirs/desi/cosmosim/Abacus/supplemental/AbacusSummit_highbase_c000_ph100/rockstar/z0.500/rockstar.cfg"
boxsize_rs = get_variable(file_path_rs, name='BOX_SIZE')
print(f"Box size Rockstar: {boxsize_rs}")
# Out:
# Box size Rockstar: 1000

# %%
print(f"Nombre de halos Rockstar : {len(Mhalos_RS):,}".replace(',', ' '))
print(f"Nombre de halos CompaSO  : {len(Mhalos_CS):,}".replace(',', ' '))
# Out:
# Nombre de halos Rockstar : 12 355 055
# Nombre de halos CompaSO  : 12 134 964

# %%
def filter_nested_halos(positions, radii, masses, boxsize=None, verbose=True):
    """
    Élimine les halos contenus dans un halo plus massif (centre-à-centre < rayon du plus gros halo).

    Args:
        positions (np.ndarray): (N, 3) positions des halos
        radii (np.ndarray): (N,) rayon utilisé pour exclusion (par exemple r100_L2com)
        masses (np.ndarray): (N,) masses des halos
        boxsize (float, optional): taille de la boîte (pour périodicité). Si None, pas de périodicité.
        verbose (bool): Affiche les stats si True

    Returns:
        isolated_mask (np.ndarray): booléen (N,), True si le halo est isolé
    """
    N = len(positions)
    assert positions.shape == (N, 3)
    assert radii.shape == (N,)
    assert masses.shape == (N,)

    # Trier par masse décroissante
    sorted_idx = np.argsort(-masses)
    positions = positions[sorted_idx]
    radii = radii[sorted_idx]
    masses = masses[sorted_idx]

    # KDTree
    tree = cKDTree(positions, boxsize=boxsize)

    contained = np.zeros(N, dtype=bool)

    for i in range(N):
        if contained[i]:
            continue  # déjà inclus par un halo plus massif

        # Trouver tous les voisins dans le rayon du halo i
        neighbors = tree.query_ball_point(positions[i], r=radii[i])

        # Marquer tous les halos moins massifs (index > i) comme contenus
        for j in neighbors:
            if j > i:
                contained[j] = True

        # Nettoyage périodique mémoire si N est grand
        if i % 10000 == 0:
            process = psutil.Process()
            ram_used = process.memory_info().rss / 1e9
            print(f"Halo {i:>7} / {N:>7} — RAM utilisée : {ram_used:.2f} GB")
            gc.collect()

    # Création du masque isolé
    isolated_mask = ~contained

    if verbose:
        print(f"Total halos : {N:,}".replace(',', ' '))
        print(f"Isolated halos : {np.sum(isolated_mask):,}".replace(',', ' '))
        print(f"Nested halos removed : {np.sum(contained):,}".replace(',', ' '))

    # Retourner le masque dans l’ordre initial (non trié)
    reindexed_mask = np.zeros_like(isolated_mask)
    reindexed_mask[sorted_idx] = isolated_mask

    return reindexed_mask

# %%
isolated_mask = filter_nested_halos(positions_cs, radii_cs, Mhalos_CS, boxsize=boxsize_cs, verbose=True)
positions_cs = positions_cs[isolated_mask]
# Out:
# Halo       0 / 12134964 — RAM utilisée : 4.85 GB
# Halo   10000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   20000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   30000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   40000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   50000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   60000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   80000 / 12134964 — RAM utilisée : 4.85 GB
# Halo   90000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo  990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 1990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 2990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 3990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 4990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 5990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 6990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 7990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 8990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 9990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10700000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10870000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 10990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11130000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11140000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11150000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11160000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11170000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11180000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11190000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11200000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11210000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11220000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11230000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11240000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11250000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11260000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11270000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11280000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11290000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11300000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11310000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11320000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11330000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11340000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11350000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11360000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11370000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11380000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11390000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11400000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11410000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11420000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11430000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11440000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11450000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11460000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11470000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11480000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11490000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11500000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11510000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11520000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11530000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11540000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11550000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11560000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11570000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11580000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11590000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11600000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11610000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11620000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11630000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11640000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11650000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11660000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11670000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11680000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11690000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11710000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11720000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11730000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11740000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11750000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11760000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11770000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11780000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11790000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11800000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11810000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11820000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11830000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11840000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11850000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11860000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11880000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11890000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11900000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11910000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11920000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11930000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11940000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11950000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11960000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11970000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11980000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 11990000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12000000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12010000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12020000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12030000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12040000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12050000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12060000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12070000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12080000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12090000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12100000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12110000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12120000 / 12134964 — RAM utilisée : 4.85 GB
# Halo 12130000 / 12134964 — RAM utilisée : 4.85 GB
# Total halos : 12 134 964
# Isolated halos : 11 932 765
# Nested halos removed : 202 199

# %%
Mhalos_CS = Mhalos_CS[isolated_mask]
radii_cs = radii_cs[isolated_mask]

# %% [markdown]
# # Mass study

# %%
colors_list = ['green', 'red'] 
colors_ratio=['blue']
labels_name = ['CompaSO', 'Rockstar']
labels_scale = ['Linear', 'Log']
labels_ratio = ['Rockstar / Compaso']

# %% [markdown]
# ## Bins

# %%
# Linear bins
bins = np.histogram_bin_edges(np.concatenate([Mhalos_RS, Mhalos_CS]), bins=50)

# Show bins
min_min_mass = min(Mhalos_RS.min(), Mhalos_CS.min())
max__max_mass = max(Mhalos_RS.max(), Mhalos_CS.max())

bins_log_tot = np.logspace(np.log10(min_min_mass), np.log10(max__max_mass), num=50)
bins_log_centers_tot = 0.5 * (bins_log_tot[:-1] + bins_log_tot[1:])

# Logarithmic bins
min_mass = max(Mhalos_RS.min(), Mhalos_CS.min())
max_mass = min(Mhalos_RS.max(), Mhalos_CS.max())

bins_log = np.logspace(np.log10(min_mass), np.log10(max_mass), num=30)
bins_log_centers = 0.5 * (bins_log[:-1] + bins_log[1:])

print(f"Minimum log bins : {bins_log[0]:.2e}")
print(f"Max log bins : {bins_log[29]:.2e}")
# Out:
# Minimum log bins : 3.16e+11
# Max log bins : 1.17e+15

# %%
mask_CS = (Mhalos_CS > bins_log[0]) & (Mhalos_CS < bins_log[-1])
mask_RS = (Mhalos_RS > bins_log[0]) & (Mhalos_RS < bins_log[-1])

print(f"Halos CS in bins : {np.sum(mask_CS):,}".replace(',', ' '))
print(f"Halos RS in bins : {np.sum(mask_RS):,}".replace(',', ' '))
print("Ratio inside bins:", np.sum(mask_RS) / np.sum(mask_CS))
# Out:
# Halos CS in bins : 11 857 203
# Halos RS in bins : 12 279 066
# Ratio inside bins: 1.035578626763833

# %% [markdown]
# ## HMF

# %%
hmf_rs_log_tot, bin_centers_rs_log_tot = compute_hmf(Mhalos_RS, bins_log_tot)
hmf_cs_log_tot, bin_centers_cs_log_tot = compute_hmf(Mhalos_CS, bins_log_tot)

hmf_rs_log, bin_centers_rs_log = compute_hmf(Mhalos_RS, bins_log)
hmf_cs_log, bin_centers_cs_log = compute_hmf(Mhalos_CS, bins_log)

# %%
data_hmf_tot = [hmf_cs_log_tot, hmf_rs_log_tot]
bins_hmf_tot = [bin_centers_cs_log_tot, bin_centers_rs_log_tot]

plot_masses_fct(data_hmf_tot, bins_hmf_tot, colors_list, labels_name, linestyles_list=['none','none'], title='Halo Mass Function (HMF), log bins', ylabel=r'$\frac{dN}{dM} \, [(M_\odot)^{-1}]$')

data_hmf = [hmf_cs_log, hmf_rs_log]
bins_hmf = [bin_centers_cs_log, bin_centers_rs_log]

plot_masses_fct(data_hmf, bins_hmf, colors_list, labels_name, linestyles_list=['none','none'], title='Halo Mass Function (HMF), log bins', ylabel=r'$\frac{dN}{dM} \, [(M_\odot)^{-1}]$')

# %%
plot_masses_fct([hmf_rs_log / hmf_cs_log], 
                [bin_centers_rs_log], colors_list=colors_ratio, 
                labels_list=labels_ratio, linestyles_list=['none'], 
                scale='semilogx', title='HMF ratio, log bins', 
                ylabel=r'$\frac{dN}{dM} \, [(M_\odot)^{-1}]$',
                center_around_one=True, margin_factor=0.1)

# %%
print(len(Mhalos_RS) / len(Mhalos_CS))

print(np.sum(hmf_rs_log) / np.sum(hmf_cs_log))
# Out:
# 1.0353891155989412
# 1.035578626763833

# %% [markdown]
# # Correlation function

# %%
positions_rs = positions_RS % boxsize_cs

x_cs, y_cs, z_cs = positions_cs[:, 0], positions_cs[:, 1], positions_cs[:, 2]
x_rs, y_rs, z_rs = positions_rs[:, 0], positions_rs[:, 1], positions_rs[:, 2]

# %% [markdown]
# ## SMU

# %%
bins_s = np.linspace(0, 100, 51)  # Distance intervals in Mpc/h
bins_mu = np.linspace(-1, 1, 101)    # Angle cosine intervals

bins_log_s = np.logspace(np.log10(0.01), np.log10(100), 30)

# %%
ells = (0, 2, 4)
wedges = (-1., -2./3, -1./3, 0., 1./3, 2./3, 1.)

# %% [markdown]
# ### Download

# %%
data_smu_cs = np.load('/pscratch/sd/g/guittonm/smu_cs_rem.npz', allow_pickle=True)
 
results_smu_cs = data_smu_cs['results_smu_cs'].item()
rp_cs = data_smu_cs['rp_cs'] 
xi_cs = data_smu_cs['xi_cs']

data_smu_rs = np.load('/pscratch/sd/g/guittonm/smu_rs_rem.npz', allow_pickle=True)
 
results_smu_rs = data_smu_rs['results_smu_rs'].item()
rp_rs = data_smu_rs['rp_rs'] 
xi_rs = data_smu_rs['xi_rs']

# %%
data_smu_cs_log = np.load('/pscratch/sd/g/guittonm/smu_log_cs_rem.npz', allow_pickle=True)
 
results_smu_cs_log = data_smu_cs_log['results_smu_cs_log'].item()
rp_cs_log = data_smu_cs_log['rp_cs_log'] 
xi_cs_log = data_smu_cs_log['xi_cs_log']

data_smu_rs_log = np.load('/pscratch/sd/g/guittonm/smu_log_rs_rem.npz', allow_pickle=True)
 
results_smu_rs_log = data_smu_rs_log['results_smu_rs_log'].item()
rp_rs_log = data_smu_rs_log['rp_rs_log'] 
xi_rs_log = data_smu_rs_log['xi_rs_log']

# %% [markdown]
# ### Plots

# %%
# ## CompaSO

# results_smu_cs = TwoPointCorrelationFunction(
#     mode='smu',  
#     edges=(bins_s, bins_mu),  # Distance markers for bins
#     data_positions1=(x_cs, y_cs, z_cs),  # Halo positions
#     boxsize=boxsize_cs,  
#     los='z',
#     nthreads=55
# )

# # Results
# xi_cs = results_smu_cs.corr  # Values of 2PCF
# rp_cs = results_smu_cs.sep  # Corresponding distances

# print('Shape of s :', rp_cs.shape)  # Should be dimension (n,)
# print(f'Shape of xi(s) : {xi_cs.shape}')

# %%
print_multipoles(results_smu_cs, ells, title = 'CompaSO')

# %%
# ## Rockstar

# results_smu_rs = TwoPointCorrelationFunction(
#     mode='smu',  
#     edges=(bins_s, bins_mu),  # Distance markers for bins 
#     data_positions1=(x_rs, y_rs, z_rs),  # Halo positions
#     boxsize=boxsize_rs,      
#     los='z',
#     nthreads=55
# )   
 
# # Results 
# xi_rs = results_smu_rs.corr  # Values of 2PCF  
# rp_rs = results_smu_rs.sep  # Corresponding distances
 
# print('Shape of s :', rp_rs.shape)  # Should be dimension (n,)
# print(f'Shape of xi(s) : {xi_rs.shape}')

# %%
print_multipoles(results_smu_rs, ells, title = 'Rockstar')

# %%
results_smu_list = [results_smu_cs, results_smu_rs]
colors_smu = ['deepskyblue', 'lightpink', 'springgreen', 'dodgerblue', 'deeppink', 'seagreen']

print_many_multipoles(results_list=results_smu_list, labels=['CompaSO', 'Rockstar'], colors_list=colors_smu, ells=ells, title='Rockstar vs compaSO')

# %%
# np.savez('/pscratch/sd/g/guittonm/smu_cs_rem.npz', 
#          results_smu_cs=results_smu_cs,
#          rp_cs=rp_cs, 
#          xi_cs=xi_cs)

# np.savez('/pscratch/sd/g/guittonm/smu_rs_rem.npz', 
#          results_smu_rs=results_smu_rs,
#          rp_rs=rp_rs, 
#          xi_rs=xi_rs)

# %% [markdown]
# ### log

# %%
# ## CompaSO

# results_smu_cs_log = TwoPointCorrelationFunction(
#     mode='smu',  
#     edges=(bins_log_s, bins_mu),  # Distance markers for bins
#     data_positions1=(x_cs, y_cs, z_cs),  # Halo positions
#     boxsize=boxsize_cs,  
#     los='z',
#     nthreads=55
# )

# # Results
# xi_cs_log = results_smu_cs_log.corr  # Values of 2PCF
# rp_cs_log = results_smu_cs_log.sep  # Corresponding distances

# %%
print_multipoles_log(results_smu_cs_log, ells, title = 'CompaSO - log')

# %%
# np.savez('/pscratch/sd/g/guittonm/smu_log_cs_rem.npz', 
#          results_smu_cs_log=results_smu_cs_log,
#          rp_cs_log=rp_cs_log, 
#          xi_cs_log=xi_cs_log)

# %%
# ## Rockstar

# results_smu_rs_log = TwoPointCorrelationFunction(
#     mode='smu',  
#     edges=(bins_log_s, bins_mu),  # Distance markers for bins
#     data_positions1=(x_rs, y_rs, z_rs),  # Halo positions
#     boxsize=boxsize_rs,  
#     los='z', 
#     nthreads=55
# )    

# # Results 
# xi_rs_log = results_smu_rs_log.corr  # Values of 2PCF 
# rp_rs_log = results_smu_rs_log.sep  # Corresponding distances

# %%
print_multipoles_log(results_smu_rs_log, ells, title = 'Rockstar - log')

# %%
# np.savez('/pscratch/sd/g/guittonm/smu_log_rs_rem.npz', 
#          results_smu_rs_log=results_smu_rs_log,
#          rp_rs_log=rp_rs_log, 
#          xi_rs_log=xi_rs_log)

# %%
results_smu_log_list = [results_smu_cs_log, results_smu_rs_log]
colors_smu = ['deepskyblue', 'lightpink', 'springgreen', 'dodgerblue', 'deeppink', 'seagreen']

print_many_multipoles_log(results_list=results_smu_log_list, labels=['CompaSO', 'Rockstar'], colors_list=colors_smu, ells=ells, title='Rockstar vs compaSO')

# %%
pairs_s_cs = results_smu_cs_log.D1D2.wcounts
pairs_s_rs = results_smu_rs_log.D1D2.wcounts    # Somme sur mu

# Vérification de la forme des données
print("Shape of pairs_s_cs:", pairs_s_cs.shape)
print("Shape of pairs_s_rs:", pairs_s_rs.shape)

# Somme sur mu pour obtenir le nombre de paires par bin de s
pairs_s_cs_summed = np.sum(pairs_s_cs, axis=-1)  
pairs_s_rs_summed = np.sum(pairs_s_rs, axis=-1)

# Création du masque : où la somme des paires n’est pas nulle
mask_nonzero_cs = pairs_s_cs_summed > 0
mask_nonzero_rs = pairs_s_rs_summed > 0

# Appliquer le même masque sur les deux courbes (optionnel, tu peux aussi en faire un pour RS)
s_values_cs = bins_log_s[:-1][mask_nonzero_cs]
pairs_values_cs = pairs_s_cs_summed[mask_nonzero_cs]

s_values_rs = bins_log_s[:-1][mask_nonzero_rs]
pairs_values_rs = pairs_s_rs_summed[mask_nonzero_rs]


# Tracé
plt.figure(figsize=(8,6))
plt.loglog(s_values_cs, pairs_values_cs, label="CompaSO", marker="o", markersize=3, linestyle="-", color='green')
plt.loglog(s_values_rs, pairs_values_rs, label="Rockstar", marker="s", markersize=3, linestyle="-", color = 'red')

plt.xlabel(r"$s$ [Mpc/h]")
plt.ylabel("Number of pairs")
plt.title("Comparison of the number of pairs for each $s$")
plt.legend()
plt.grid(True, which='major', linestyle='--', alpha=0.5)
plt.show()

print(pairs_s_cs_summed[0:9])
# Out:
# Shape of pairs_s_cs: (29, 100)
# Shape of pairs_s_rs: (29, 100)
# [  0.   0.   0.   0.   0.   0.   0.   0. 232.]

# %% [markdown]
# ## RPPI

# %% [markdown]
# ### Bins

# %%
# bins_rp = np.linspace(0, 100, 101)  # (0,40,41)
bins_pi = np.linspace(-100, 100, 81)   # (-40,40,81)
bins_rp = np.logspace(np.log10(0.01), np.log10(100), 41) #np.log10(0.01)

# %% [markdown]
# ### No RSD

# %%
# ## CompaSo

# results_rppi_cs = TwoPointCorrelationFunction(
#     mode='rppi',  
#     edges=(bins_rp, bins_pi),  # Bornes des distances pour les bins
#     data_positions1=(x_cs, y_cs, z_cs),  # Positions des halos
#     nthreads=55,
#     boxsize=boxsize_cs,
#     los='z'
# )

# pi_cs = results_rppi_cs.sepavg(axis=1)
# xi_rppi_cs = results_rppi_cs.corr

# %%
# np.savez('/pscratch/sd/g/guittonm/rppi_cs_rem.npz', 
#          results_rppi_cs=results_rppi_cs,
#          pi_cs=pi_cs, 
#          xi_rppi_cs=xi_rppi_cs)

data_rppi_cs = np.load('/pscratch/sd/g/guittonm/rppi_cs_rem.npz', allow_pickle=True)

results_rppi_cs = data_rppi_cs['results_rppi_cs'].item()
pi_cs = data_rppi_cs['pi_cs']
xi_rppi_cs = data_rppi_cs['xi_rppi_cs']

# %%
sep_cs = projected_pcf(results_rppi_cs, title='CompaSO')

# %%
# ## Rockstar
 
# results_rppi_rs = TwoPointCorrelationFunction(
#     mode='rppi',  
#     edges=(bins_rp, bins_pi),  # Bornes des distances pour les bins
#     data_positions1=(x_rs, y_rs, z_rs),  # Positions des halos
#     nthreads=55,
#     boxsize=boxsize_cs, 
#     los='z'
# )

# pi_rs = results_rppi_rs.sepavg(axis=1)
# xi_rppi_rs = results_rppi_rs.corr

# %%
# np.savez('/pscratch/sd/g/guittonm/rppi_rs_pid_rem.npz', 
#          results_rppi_rs=results_rppi_rs,
#          pi_rs=pi_rs, 
#          xi_rppi_rs=xi_rppi_rs)

data_rppi_rs = np.load('/pscratch/sd/g/guittonm/rppi_rs_pid_rem.npz', allow_pickle=True)

results_rppi_rs = data_rppi_rs['results_rppi_rs'].item()
pi_rs = data_rppi_rs['pi_rs']
xi_rppi_rs = data_rppi_rs['xi_rppi_rs']

# %%
sep_rs = projected_pcf(results_rppi_rs, title='Rockstar')

# %%
sep_rs, wp_rs = results_rppi_rs(pimax=None, return_sep=True) # sep is r_p
sep_cs, wp_cs = results_rppi_cs(pimax=None, return_sep=True)

plt.figure(figsize=(7, 5))
plt.title(f'Projected Correlation Function')

# Plot CompaSO
plt.plot(sep_cs, sep_cs * wp_cs, label='CompaSO', color='green', linestyle='-')

# Plot Rockstar
plt.plot(sep_rs, sep_rs * wp_rs, label='Rockstar', color='red', linestyle='-')

# Axes and labels
plt.xscale('log')
plt.xlabel(r'$r_{p}$')
plt.ylabel(r'$r_{p} w_{p}(r_{p})$')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# ### RSD

# %%
## CompaSO

z_sim_cs = hcat.header['Redshift']
id_cs = np.array(hcat_pos['id'])
a_cs = hcat.header['ScaleFactor'] # scale factor

Hz_cs = hcat.header['HubbleNow'] * 100

velocities_cs = np.array(hcat_pos['v_L2com'])[isolated_mask]

z_rsd_cs, delta_z_cs = rsd_effect(a_cs, positions_cs, velocities_cs, Hz_cs, name='CompaSO')

## Rockstar

H0 = 100
Om_rs = get_variable(file_path_rs, name='Om')
Ol_rs = get_variable(file_path_rs, name='Ol')
z_sim_rs = extract_redshift_from_path(file_path_rs)
a_rs = Ol_rs = get_variable(file_path_rs, name='SCALE_NOW')

Hz_rs = H0 * np.sqrt(Om_rs * (1+z_sim_rs)**3 + Ol_rs)

print('Hz :', Hz_rs, '\n', 'Om_rs :', Om_rs, '\n', 'Ol_rs :', Ol_rs, '\n', 'z_sim_rs :', z_sim_rs, '\n', 'a_rs :', a_rs, '\n',)

z_rsd_rs, delta_z_rs = rsd_effect(a_rs, positions_rs, velocities_RS, Hz_rs, name='Rockstar')
# Out:
# Shape of velocities: (11932765, 3)
# Shape of positions: (11932765, 3)
#
# Hubble constant Hz: 132.23392151789199
#
# Hz : 131.54618960654088
#  Om_rs : 0.315192
#  Ol_rs : 0.666667
#  z_sim_rs : 0.5
#  a_rs : 0.666667
#
# Shape of velocities: (12355055, 3)
# Shape of positions: (12355055, 3)
#
# Hubble constant Hz: 131.54618960654088

# %%
# ## CompaSo
 
# results_rppi_cs_rsd = TwoPointCorrelationFunction(
#     mode='rppi',  
#     edges=(bins_rp, bins_pi),  # Bornes des distances pour les bins
#     data_positions1=(x_cs, y_cs, z_rsd_cs),  # Positions des halos
#     nthreads=55,
#     boxsize=boxsize_cs,
#     los='z'
# )

# pi_cs_rsd = results_rppi_cs_rsd.sepavg(axis=1) 
# xi_rppi_cs_rsd = results_rppi_cs_rsd.corr

# %%
# np.savez('/pscratch/sd/g/guittonm/rppi_cs_rsd_rem.npz', 
#          results_rppi_cs_rsd=results_rppi_cs_rsd,
#          pi_cs_rsd=pi_cs_rsd, 
#          xi_rppi_cs_rsd=xi_rppi_cs_rsd)

data_rppi_cs_rsd = np.load('/pscratch/sd/g/guittonm/rppi_cs_rsd_rem.npz', allow_pickle=True)

results_rppi_cs_rsd = data_rppi_cs_rsd['results_rppi_cs_rsd'].item()
pi_cs_rsd = data_rppi_cs_rsd['pi_cs_rsd']
xi_rppi_cs_rsd = data_rppi_cs_rsd['xi_rppi_cs_rsd']

# %%
sep_cs_rsd = projected_pcf(results_rppi_cs_rsd, title='CompaSO RSD')

# %%
## Rockstar

results_rppi_rs_rsd = TwoPointCorrelationFunction(
    mode='rppi',  
    edges=(bins_rp, bins_pi),  # Bornes des distances pour les bins
    data_positions1=(x_rs, y_rs, z_rsd_rs),  # Positions des halos
    nthreads=55,  
    boxsize=boxsize_rs,
    los='z'
) 
 
pi_rs_rsd = results_rppi_rs_rsd.sepavg(axis=1)
xi_rppi_rs_rsd = results_rppi_rs_rsd.corr

# %%
np.savez('/pscratch/sd/g/guittonm/rppi_rs_rsd_pid_rem.npz', 
         results_rppi_rs_rsd=results_rppi_rs_rsd,
         pi_rs_rsd=pi_rs_rsd, 
         xi_rppi_rs_rsd=xi_rppi_rs_rsd)

data_rppi_rs_rsd = np.load('/pscratch/sd/g/guittonm/rppi_rs_rsd_pid_rem.npz', allow_pickle=True)

results_rppi_rs_rsd = data_rppi_rs_rsd['results_rppi_rs_rsd'].item()
pi_rs_rsd = data_rppi_rs_rsd['pi_rs_rsd']
xi_rppi_rs_rsd = data_rppi_rs_rsd['xi_rppi_rs_rsd']

# %%
sep_rs_rsd = projected_pcf(results_rppi_rs_rsd, title='Rockstar RSD')

# %%
pcf_results = [results_rppi_rs, results_rppi_cs, results_rppi_rs_rsd, results_rppi_cs_rsd]
legends_pcf = ['Rockstar', 'CompaSo', 'Rockstar RSD', 'CompaSo RSD']
colors_pcf= ['red', 'green', 'pink', 'limegreen']

compa_pcf(pcf_results, legends=legends_pcf, colors=colors_pcf, title="Projected 2PCF comparison", mask_range=(0.01,100))

# %% [markdown]
# # Bias

# %%
file_path = "/pscratch/sd/g/guittonm/all_positions.npy"

# Same positions for both simulations
positions_mm = np.load(file_path, mmap_mode='r')  # mmap_mode for huge data
print(f"Total positions : {positions_mm.shape[0]}")
# Out:
# Total positions : 2538452676

# %%
# fraction = 0.02  # % of the data

# # Create a binary mask to select 10% of the data
# mask = np.random.rand(positions_mm.shape[0]) < fraction
 
# # Apply the mask
# positions_mm_sampled = positions_mm[mask]

# if positions_mm_sampled.shape[1] == 3:  # Check that it's a 2D table with 3 columns
#     positions_mm_sampled = [positions_mm_sampled[:, 0], positions_mm_sampled[:, 1], positions_mm_sampled[:, 2]]  # Separate x, y, z

# %%
# np.savez('/pscratch/sd/g/guittonm/pos_mm_rem.npz', 
#          positions_mm_sampled=positions_mm_sampled)    
 
data_pos_mm = np.load('/pscratch/sd/g/guittonm/pos_mm_rem.npz') 
 
positions_mm_sampled = data_pos_mm['positions_mm_sampled']

# %%
# ## SMU

# results_smu_mm = TwoPointCorrelationFunction(
#     mode='smu',  
#     edges=(bins_s, bins_mu),  # Distance markers for bins
#     data_positions1=positions_mm_sampled,  # Particles positions
#     boxsize=boxsize_cs,  
#     los='z',
#     nthreads=55
# )

# xi_mm = results_smu_mm.corr

# %%
# np.savez('/pscratch/sd/g/guittonm/smu_mm_rem.npz',  
#          results_smu_mm=results_smu_mm,
#          xi_mm=xi_mm)    
 
data_smu_mm = np.load('/pscratch/sd/g/guittonm/smu_mm_rem.npz', allow_pickle=True)
 
results_smu_mm = data_smu_mm['results_smu_mm'].item()  
xi_mm = data_smu_mm['xi_mm']

# %%
r_mm_mono, xi_mm_mono = results_smu_mm(ells=(0,), return_sep=True)

# %%
r_cs_quad, xi_cs_quad = results_smu_cs(ells=(2,), return_sep=True)
r_rs_quad, xi_rs_quad = results_smu_rs(ells=(2,), return_sep=True)
r_mm_quad, xi_mm_quad = results_smu_mm(ells=(2,), return_sep=True)

# %%
print_chosen_multipole(
    [r_cs_quad, r_rs_quad, r_mm_quad], 
    [xi_cs_quad, xi_rs_quad, xi_mm_quad], 
    ["CompaSO", "Rockstar", "Particles"], 
    "Quadrupoles",
    colors_list = ['green', 'red', 'blue']
)

plot_multipole_ratio(r_cs_quad, xi_cs_quad, xi_rs_quad, yrange=None, mask_range=None, l='2', title = "Ratio between CompaSO and Rockstar Quadrupoles", label=r"$\xi_{\mathrm{Rockstar}} / \xi_{\mathrm{CompaSo}}$")

# %% [markdown]
# ### Bins

# %%
bin_edges_exp = [11.5, 11.75, 12, 12.5, 13, 15.5]

mass_bins = np.power(10, bin_edges_exp)

# %%
# print('CompaSo')
# bias_mono_cs, bias_quad_cs = bias_wrt_mass(mass_bins, Mhalos_CS, positions_cs, bins_s, bins_mu, boxsize_cs, xi_mm_mono, xi_mm_quad, mask_range=(None,None), save_path="/pscratch/sd/g/guittonm/xi_hh_mass_bins_cs_rem.npz")
# print('\n', 'Rockstar')
# bias_mono_rs, bias_quad_rs = bias_wrt_mass(mass_bins, Mhalos_RS, positions_rs, bins_s, bins_mu, boxsize_rs, xi_mm_mono, xi_mm_quad, mask_range=(None,None), save_path="/pscratch/sd/g/guittonm/xi_hh_mass_bins_rs_rem.npz")

# %%
# Charger le fichier _pid.npz
data_cs = np.load("/pscratch/sd/g/guittonm/xi_hh_mass_bins_cs_rem.npz")
data_rs = np.load("/pscratch/sd/g/guittonm/xi_hh_mass_bins_rs_rem.npz")

# Afficher les clés du fichier pour voir ce qu'il contient
print(data_cs.files)
print(data_rs.files)

# Extraire les données
mass_bins_cs = data_cs["mass_bins"]  # Bins de masse
r_hh_cs = data_cs["r_hh_all"]  # Valeurs de r pour chaque bin
xi_hh_mono_cs = data_cs["xi_hh_mono_all"]  # 2PCF monopole pour chaque bin
bias_by_r_mono_cs = data_cs["bias_by_r_mono_all"]
bias_mono_cs =  data_cs["bias_by_mass_mono"]

mass_bins_rs = data_rs["mass_bins"]  # Bins de masse
r_hh_rs = data_rs["r_hh_all"]  # Valeurs de r pour chaque bin
xi_hh_mono_rs = data_rs["xi_hh_mono_all"]  # 2PCF monopole pour chaque bin
bias_by_r_mono_rs = data_rs["bias_by_r_mono_all"]
bias_mono_rs =  data_rs["bias_by_mass_mono"]
# Out:
# ['mass_bins', 'r_hh_all', 'xi_hh_mono_all', 'xi_hh_quad_all', 'bias_by_mass_mono', 'bias_by_mass_quad', 'bias_by_r_mono_all', 'bias_by_r_quad_all']
# ['mass_bins', 'r_hh_all', 'xi_hh_mono_all', 'xi_hh_quad_all', 'bias_by_mass_mono', 'bias_by_mass_quad', 'bias_by_r_mono_all', 'bias_by_r_quad_all']

# %%
mass_centers_cs = [item[0] for item in bias_mono_cs]
bias_values_cs = [item[1] for item in bias_mono_cs]

mass_centers_rs = [item[0] for item in bias_mono_rs]
bias_values_rs = [item[1] for item in bias_mono_rs]

plot_masses_fct(data_list = [bias_values_cs, bias_values_rs],
                bins_list = [mass_centers_cs, mass_centers_rs],
                colors_list = colors_list,
                labels_list = labels_name,
                linestyles_list=['-','-'],
                ylabel = r'$b^2(M)$',
                title=r"Mean of $b^2(M)$ / bin",
                scale = 'semilogx', center_around_one=False)

np_bias_values_rs = np.array(bias_values_rs)
np_bias_values_cs = np.array(bias_values_cs)

bias_ratio = np_bias_values_rs / np_bias_values_cs

plot_masses_fct(data_list = [bias_ratio],
                bins_list = [mass_centers_rs],
                colors_list = colors_ratio,
                labels_list = labels_ratio,
                linestyles_list=['-'],
                ylabel = r'$b^2_{\mathrm{RS}} \,/\, b^2_{\mathrm{CS}}$',
                title = r"Ratio $b^2(M)$",
                scale = 'semilogx', center_around_one=True)

# %%
## CompaSo

plot_mass_binned_quantity(
    r_hh_all=r_hh_cs, 
    quantity_all=xi_hh_mono_cs,  
    mass_bins=mass_bins,
    ylabel=r'$r^2 \xi_{0}(r)$',
    title='2PCF Monopoles by Mass Bins - CompaSo',
    apply_transformation=lambda r, q: r * r * q.squeeze(),  # Transformation spécifique pour la 2PCF
    mask_range=(0,100),
    yrange=(-15,100),
    scalex=None,
    scaley=None
)

## Rockstar 

plot_mass_binned_quantity(
    r_hh_all=r_hh_rs, 
    quantity_all=xi_hh_mono_rs,  
    mass_bins=mass_bins,
    ylabel=r'$r^2 \xi_{0}(r)$',
    title='2PCF Monopoles by Mass Bins - Rockstar',
    apply_transformation=lambda r, q: r * r * q.squeeze(),  # Transformation spécifique pour la 2PCF
    mask_range=(0,100),
    yrange=(-15,100),
    scalex=None,
    scaley=None
)

# %%
plot_mass_ratio_comparison(
    r_hh_all_cs=r_hh_cs, quantity_all_cs=xi_hh_mono_cs, errors_cs=False,
    r_hh_all_rs=r_hh_rs, quantity_all_rs=xi_hh_mono_rs, errors_rs=False,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$r^2 \xi_{0}(r)$',
    title="Halo 2PCF Comparison: CompaSo vs Rockstar, smu, 100%",
    apply_transformation=lambda r, q: r * r * q.squeeze(),  # Transformation pour la 2PCF
    rows=2,  # Affichage sur 2 lignes,
    mask_range=(0,100), ratio_yrange=(0.7,1.3),
    scaley=None, scalex=None,
    ratio_leg='upper left', leg_pos='lower left'
)

# %%
plot_mass_ratio_comparison(
    r_hh_all_cs=r_hh_cs, quantity_all_cs=xi_hh_mono_cs, errors_cs=False,
    r_hh_all_rs=r_hh_rs, quantity_all_rs=xi_hh_mono_rs, errors_rs=False,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$r^2 \xi_{0}(r)$',
    title="Halo 2PCF Comparison: CompaSo vs Rockstar",
    apply_transformation=lambda r, q: r * r * q.squeeze(),  # Transformation pour la 2PCF
    rows=2,  # Affichage sur 2 lignes,
    mask_range=(0,80), ratio_yrange=(0.8,1.2),
    scaley=None, scalex='log',
    ratio_leg='upper left', leg_pos='lower left'
)

# %%
plot_ratio_comparison(
    r_hh_all_cs=r_hh_cs, quantity_all_cs=xi_hh_mono_cs,
    r_hh_all_rs=r_hh_rs, quantity_all_rs=xi_hh_mono_rs,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$\xi_{\mathrm{RS}} / \xi_{\mathrm{CS}}$',
    title="Halo 2PCF Ratio: CompaSo vs Rockstar",
    apply_transformation=lambda r, q: r * r * q.squeeze(),
    yrange=(0.5, 1.8),
    mask_range=(0,80),
    rows=2  # Affichage sur 2 lignes
)

# %%
## CompaSo
plot_mass_binned_quantity(
    r_hh_all=r_hh_cs, 
    quantity_all=bias_by_r_mono_cs,  
    mass_bins=mass_bins,
    ylabel=r'$b^2(M)$',
    title='Halo Bias wrt r - CompaSo',
    mask_range=(0,80),
    yrange=(-5,15),
    scalex=None,
    scaley=None
)

## Rockstar
plot_mass_binned_quantity(
    r_hh_all=r_hh_rs, 
    quantity_all=bias_by_r_mono_rs,  
    mass_bins=mass_bins,
    ylabel=r'$b^2(M)$',
    title='Halo Bias wrt r - Rockstar',
    mask_range=(0,80),
    yrange=(-5,20),
    scalex=None,
    scaley=None
)

# %%
plot_mass_ratio_comparison(
    r_hh_all_cs=r_hh_cs, quantity_all_cs=bias_by_r_mono_cs, errors_cs=False,
    r_hh_all_rs=r_hh_rs, quantity_all_rs=bias_by_r_mono_rs, errors_rs=False,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$b^2(M)$',
    title="Halo Bias Comparison: CompaSo vs Rockstar",
    rows=2, scaley=None,
    yrange = (0, 14), ratio_yrange=(0.8,1.2),
    mask_range = (0, 75), leg_pos='upper left', ratio_leg='upper right'
)

# %%
plot_ratio_comparison(
    r_hh_all_cs=r_hh_cs, quantity_all_cs=bias_by_r_mono_cs,
    r_hh_all_rs=r_hh_rs, quantity_all_rs=bias_by_r_mono_rs,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$b^2_{\mathrm{RS}} / b^2_{\mathrm{CS}}$',
    title="Halo Bias Ratio: CompaSo vs Rockstar",
    yrange=(0.8, 1.8),
    mask_range=(0,75),
    rows=2  # Affichage sur 2 lignes
)

# %% [markdown]
# ## RPPI wrt mass bin

# %%
# wp_cs, rp_cs = xi_wrt_mass(mass_bins, Mhalos_CS, positions_cs, bins_rp, bins_pi, boxsize_cs, save_path="/pscratch/sd/g/guittonm/rppi_mass_bins_cs_bs_rem.npz", mask_range=(None, None), nthreads=55)

# wp_rs, rp_rs = xi_wrt_mass(mass_bins, Mhalos_RS, positions_rs, bins_rp, bins_pi, boxsize_cs, save_path="/pscratch/sd/g/guittonm/rppi_mass_bins_rs_bs_rem.npz", mask_range=(None, None), nthreads=55)

# %%
# Charger le fichier _pid.npz
data_cs_rppi = np.load("/pscratch/sd/g/guittonm/rppi_mass_bins_cs_bs_rem.npz")
data_rs_rppi = np.load("/pscratch/sd/g/guittonm/rppi_mass_bins_rs_bs_rem.npz")

# Afficher les clés du fichier pour voir ce qu'il contient
print(data_cs_rppi.files)
print(data_rs_rppi.files)

# Extraire les données
mass_bins_cs_rppi = data_cs_rppi["mass_bins"]  # Bins de masse
rp_cs = data_cs_rppi["rp_all"] 
wp_cs = data_cs_rppi["wp_all"] 

mass_bins_rs_rppi = data_rs_rppi["mass_bins"]  # Bins de masse
rp_rs = data_rs_rppi["rp_all"]  
wp_rs = data_rs_rppi["wp_all"]
# Out:
# ['mass_bins', 'rp_all', 'wp_all']
# ['mass_bins', 'rp_all', 'wp_all']

# %%
plot_mass_binned_quantity(
    r_hh_all=rp_cs, 
    quantity_all=wp_cs,  
    mass_bins=mass_bins,
    scaley=None,
    ylabel=r'$r_{p} w_{p}(r_{p})$',
    title='2PCF Monopoles by Mass Bins - CompaSo',
    apply_transformation=lambda r, q: r * q.squeeze()  # Transformation spécifique pour la 2PCF
)

plot_mass_binned_quantity(
    r_hh_all=rp_rs, 
    quantity_all=wp_rs,  
    mass_bins=mass_bins,
    scaley=None,
    ylabel=r'$r_{p} w_{p}(r_{p})$',
    title='2PCF Monopoles by Mass Bins - Rockstar',
    apply_transformation=lambda r, q: r * q.squeeze()  # Transformation spécifique pour la 2PCF
)

# %%
plot_mass_ratio_comparison(
    r_hh_all_cs=rp_cs, quantity_all_cs=wp_cs, errors_cs = False,
    r_hh_all_rs=rp_rs, quantity_all_rs=wp_rs, errors_rs = False,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$r_{p} w_{p}(r_{p})$',
    title="Projected PCF CompaSo vs Rockstar, rppi, 100%",
    rows=2,
    apply_transformation=lambda r, q: r * q.squeeze(),
    scalex='log',
    scaley=None, ratio_yrange=(0.8,1.2), ratio_leg='upper left', leg_pos='upper center'
)

# %%
## RSD

positions_cs_rsd = np.vstack((x_cs, y_cs, z_rsd_cs)).T
positions_rs_rsd = np.vstack((x_rs, y_rs, z_rsd_rs)).T

# wp_cs_rsd, rp_cs_rsd = xi_wrt_mass(mass_bins, Mhalos_CS, positions_cs_rsd, bins_rp, bins_pi, boxsize_cs, save_path="/pscratch/sd/g/guittonm/rppi_mass_bins_cs_rsd_rem.npz", mask_range=(None, None), nthreads=55)
# wp_rs_rsd, rp_rs_rsd = xi_wrt_mass(mass_bins, Mhalos_RS, positions_rs_rsd, bins_rp, bins_pi, boxsize_cs, save_path="/pscratch/sd/g/guittonm/rppi_mass_bins_rs_rsd_rem.npz", mask_range=(None, None), nthreads=55)

# %%
# Charger le fichier _pid.npz
data_cs_rppi_rsd = np.load("/pscratch/sd/g/guittonm/rppi_mass_bins_cs_rsd_rem.npz")
data_rs_rppi_rsd = np.load("/pscratch/sd/g/guittonm/rppi_mass_bins_rs_rsd_rem.npz")

# Afficher les clés du fichier pour voir ce qu'il contient
print(data_cs_rppi_rsd.files)
print(data_rs_rppi_rsd.files)

# Extraire les données
mass_bins_cs_rppi_rsd = data_cs_rppi_rsd["mass_bins"]  # Bins de masse
rp_cs_rsd = data_cs_rppi_rsd["rp_all"] 
wp_cs_rsd = data_cs_rppi_rsd["wp_all"] 

mass_bins_rs_rppi_rsd = data_rs_rppi_rsd["mass_bins"]  # Bins de masse
rp_rs_rsd = data_rs_rppi_rsd["rp_all"]  
wp_rs_rsd = data_rs_rppi_rsd["wp_all"]
# Out:
# ['mass_bins', 'rp_all', 'wp_all']
# ['mass_bins', 'rp_all', 'wp_all']

# %%
plot_mass_binned_quantity(
    r_hh_all=rp_cs_rsd, 
    quantity_all=wp_cs_rsd,  
    mass_bins=mass_bins,
    scaley=None,
    ylabel=r'$r_{p} w_{p}(r_{p})$',
    title='2PCF Monopoles by Mass Bins RSD - CompaSo',
    apply_transformation=lambda r, q: r * q.squeeze()  # Transformation spécifique pour la 2PCF
)

plot_mass_binned_quantity(
    r_hh_all=rp_rs_rsd, 
    quantity_all=wp_rs_rsd,  
    mass_bins=mass_bins,
    scaley=None,
    ylabel=r'$r_{p} w_{p}(r_{p})$',
    title='2PCF Monopoles by Mass Bins RSD - Rockstar',
    apply_transformation=lambda r, q: r * q.squeeze()  # Transformation spécifique pour la 2PCF
)

# %%
plot_mass_ratio_comparison(
    r_hh_all_cs=rp_cs_rsd, quantity_all_cs=wp_cs_rsd, errors_cs = False,
    r_hh_all_rs=rp_rs_rsd, quantity_all_rs=wp_rs_rsd, errors_rs = False,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$r_{p} w_{p}(r_{p})$',
    title="Projected PCF CompaSo vs Rockstar - RSD - 100%",
    rows=2,
    apply_transformation=lambda r, q: r * q.squeeze(),
    scalex='log', ratio_yrange=(0.8,1.2),
    scaley=None, leg_pos='upper right', ratio_leg='upper center'
)

# %% [markdown]
# ### Bootstrap

# %%
# print('CompaSo')
# bias_mono_cs_bs, bias_quad_cs_bs = bootstrap_bias_wrt_mass(mass_bins, Mhalos_CS, positions_cs, bins_s, bins_mu, boxsize_cs, xi_mm_mono, xi_mm_quad, mask_range=(None,None), save_path="/pscratch/sd/g/guittonm/xi_hh_mass_bins_cs_bs_rem.npz")
# print('\n', 'Rockstar')
# bias_mono_rs_bs, bias_quad_rs_bs = bootstrap_bias_wrt_mass(mass_bins, Mhalos_RS, positions_rs, bins_s, bins_mu, boxsize_rs, xi_mm_mono, xi_mm_quad, mask_range=(None,None), save_path="/pscratch/sd/g/guittonm/xi_hh_mass_bins_rs_bs_rem.npz")

# %%
# Charger le fichier _pid.npz
data_cs_bs = np.load("/pscratch/sd/g/guittonm/xi_hh_mass_bins_cs_bs_rem.npz")
data_rs_bs = np.load("/pscratch/sd/g/guittonm/xi_hh_mass_bins_rs_bs_rem.npz")

# Afficher les clés du fichier pour voir ce qu'il contient
print(data_cs_bs.files)
print(data_rs_bs.files)
 
## CompaSo 
mass_bins_cs_bs = data_cs_bs["mass_bins"]  # Bins de masse 
r_hh_cs_bs = data_cs_bs["r_hh_all"]  # Valeurs de r pour chaque bin
  
xi_hh_mono_cs_bs = data_cs_bs["xi_hh_mono_all"]  # 2PCF monopole pour chaque bin 
xi_hh_quad_cs_bs = data_cs_bs["xi_hh_quad_all"]

bias_by_r_mono_cs_bs = data_cs_bs["bias_by_r_mono_all"]
bias_by_r_quad_cs_bs = data_cs_bs["bias_by_r_quad_all"] 

mean_bias_mono_cs_bs =  data_cs_bs["mean_bias_mono_all"]
mean_bias_quad_cs_bs =  data_cs_bs["mean_bias_mono_all"]  

## Rockstar 

mass_bins_rs_bs = data_rs_bs["mass_bins"]  # Bins de masse
r_hh_rs_bs = data_rs_bs["r_hh_all"]  # Valeurs de r pour chaque bin
 
xi_hh_mono_rs_bs = data_rs_bs["xi_hh_mono_all"]  # 2PCF monopole pour chaque bin 
xi_hh_quad_rs_bs = data_rs_bs["xi_hh_quad_all"]

bias_by_r_mono_rs_bs = data_rs_bs["bias_by_r_mono_all"]
bias_by_r_quad_rs_bs = data_rs_bs["bias_by_r_quad_all"]

mean_bias_mono_rs_bs =  data_rs_bs["mean_bias_mono_all"]
mean_bias_quad_rs_bs =  data_rs_bs["mean_bias_mono_all"]
# Out:
# ['mass_bins', 'r_hh_all', 'xi_hh_mono_all', 'xi_hh_quad_all', 'bias_by_r_mono_all', 'bias_by_r_quad_all', 'mean_bias_mono_all', 'mean_bias_quad_all']
# ['mass_bins', 'r_hh_all', 'xi_hh_mono_all', 'xi_hh_quad_all', 'bias_by_r_mono_all', 'bias_by_r_quad_all', 'mean_bias_mono_all', 'mean_bias_quad_all']

# %%
plot_mass_comparison(
    r_hh_all_cs=r_hh_cs_bs, quantity_all_cs=mean_bias_mono_cs_bs, errors_cs = True,
    r_hh_all_rs=r_hh_rs_bs, quantity_all_rs=mean_bias_mono_rs_bs, errors_rs = True,
    mass_bins=mass_bins, bin_edges_exp=bin_edges_exp,
    ylabel=r'$b^2(M)$',
    title="Halo Bias Comparison: CompaSo vs Rockstar",
    rows=2,
    yrange = (-1, 12),
    mask_range=(0,75),
    scalex=None,
    scaley=None
)

# %%
n_bins = len(mass_bins) - 1

bias_values_cs = np.array([np.mean(mean_bias_mono_cs_bs[i][0]) for i in range(n_bins)])
bias_errors_cs = np.array([np.mean(mean_bias_mono_cs_bs[i][1]) for i in range(n_bins)])

bias_values_rs = np.array([np.mean(mean_bias_mono_rs_bs[i][0]) for i in range(n_bins)])
bias_errors_rs = np.array([np.mean(mean_bias_mono_rs_bs[i][1]) for i in range(n_bins)])

# Milieu des bins de masse
bias_masses_cs = 0.5 * (mass_bins[:-1] + mass_bins[1:])
bias_masses_rs = 0.5 * (mass_bins[:-1] + mass_bins[1:])

# %%
plot_masses_fct(data_list = [bias_values_cs, bias_values_rs],
                bins_list = [mass_centers_cs, mass_centers_rs],
                colors_list = colors_list,
                labels_list = labels_name,
                linestyles_list=['-', '-'],
                ylabel = r'$b^2(M)$', 
                title = "Halo Bias vs Mass with Bootstrap Uncertainty",
                scale = 'semilogx',
                errors_list = [bias_errors_cs, bias_errors_rs])
# Out:
# /global/u2/g/guittonm/functions.py:552: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(bins, data, yerr=errors, fmt='o-', label=label,

# %% [markdown]
# ### Bootstrap removing

# %%
print('CompaSo')
bias_mono_cs_bs_rm, bias_quad_cs_bs_rm = removing_bias_wrt_mass(mass_bins, Mhalos_CS, positions_cs, bins_s, bins_mu, boxsize_cs, xi_mm_mono, xi_mm_quad, mask_range=(None,None), save_path="/pscratch/sd/g/guittonm/xi_hh_mass_bins_cs_bs_rm_rem.npz")
print('\n', 'Rockstar')
bias_mono_rs_bs_rm, bias_quad_rs_bs_rm = removing_bias_wrt_mass(mass_bins, Mhalos_RS, positions_rs, bins_s, bins_mu, boxsize_rs, xi_mm_mono, xi_mm_quad, mask_range=(None,None), save_path="/pscratch/sd/g/guittonm/xi_hh_mass_bins_rs_bs_rm_rem.npz")
# Out:
# CompaSo
# Mass bin 0: 5099065 halos
# Mass bin 1: 2958931 halos
# Mass bin 2: 2687816 halos
# Mass bin 3: 865958 halos
# Mass bin 4: 320995 halos
#
#  Fichier enregistré : /pscratch/sd/g/guittonm/xi_hh_mass_bins_cs_bs_rm_rem.npz
#
#  Rockstar
# Mass bin 0: 5162740 halos
# Mass bin 1: 3055080 halos
# Mass bin 2: 2840231 halos
# Mass bin 3: 938735 halos
# Mass bin 4: 358269 halos
#
#  Fichier enregistré : /pscratch/sd/g/guittonm/xi_hh_mass_bins_rs_bs_rm_rem.npz
